# %% [markdown]
# <a href="https://colab.research.google.com/github/MingSheng92/Image_Classification/blob/master/Bernoulli_NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MingSheng92/Image_Classification.git
# Out:
# Cloning into 'Image_Classification'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 153 (delta 23), reused 0 (delta 0), pack-reused 98
# Receiving objects: 100% (153/153), 148.97 KiB | 13.54 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %load /content/Image_Classification/scripts/preprocess.py
# %load /content/Image_Classification/scripts/PCA.py
# %load /content/Image_Classification/scripts/Bernoulli_NB.py
# %load /content/Image_Classification/scripts/utility.py

from Image_Classification.scripts.preprocess import load_data, normalize, one_hot, flatten_image
from Image_Classification.scripts.Bernoulli_NB import NaiveBayes
from Image_Classification.scripts.PCA import PCA
from Image_Classification.scripts.utility import plot_predictions

import numpy as np
import keras
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#dataset='fashion_mnist'
dataset='mnist'
# load data set 
x_train, y_train, x_test, y_test = load_data(dataset, reshape=False)

# normalize the data set
x_train = normalize(x_train)
x_test = normalize(x_test)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train = flatten_image(x_train)
x_test = flatten_image(x_test)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
from datetime import datetime

# clock starting time
st_time = datetime.now()
# create new naiveBayes class object with dataset and label
# Training of data set here
NB = NaiveBayes(x_train, y_train)
# generate image and class frequency
NB.GenImageFreq()
# calculate posterior mean of the dataset
NB.GenPosteriorMean()
print("Time taken to train classifier :", (datetime.now() - st_time))
# Out:
# Time taken to train classifier : 0:01:20.890644

# %%
acc, predictions = NB.getPredictions(x_test, y_test)
# Out:
# Accuracy :  84.3
# Time to compute prediction : 0:02:43.783522  Dataset size: 10000

# %%
NB.plot_condition_prob()

# %%
dataset='fashion_mnist'
# load data set 
x_train, y_train, x_test, y_test = load_data(dataset, reshape=False)

# normalize the data set
x_train = normalize(x_train)
x_test = normalize(x_test)
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %%
x_train = flatten_image(x_train)
x_test = flatten_image(x_test)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# clock starting time
st_time = datetime.now()
# create new naiveBayes class object with dataset and label
# Training of data set here
NB = NaiveBayes(x_train, y_train)
# generate image and class frequency
NB.GenImageFreq()
# calculate posterior mean of the dataset
NB.GenPosteriorMean()
print("Time taken to train classifier :", (datetime.now() - st_time))
# Out:
# Time taken to train classifier : 0:01:29.470779

# %%
acc, predictions = NB.getPredictions(x_test, y_test)
# Out:
# Accuracy :  72.13
# Time to compute prediction : 0:02:44.559718  Dataset size: 10000

# %%
NB.plot_condition_prob()
